# %% [markdown]
# # Facial Expressions Dataset Overview
# # Group: 8
# # Members: Yaw Frempong, Cody Hang, Meghana Palaparthi, Carver Simkins, Harshraj Thakor

# %% [markdown]
# ### Dependencies

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv('./data/legend.csv')
del df['user.id']

# %%
df
# Out:
#                                  image    emotion
# 0      facial-expressions_2868588k.jpg      anger
# 1      facial-expressions_2868585k.jpg   surprise
# 2      facial-expressions_2868584k.jpg    disgust
# 3      facial-expressions_2868582k.jpg       fear
# 4               Aaron_Eckhart_0001.jpg    neutral
# ...                                ...        ...
# 13685            SharmilaTagore_80.jpg  HAPPINESS
# 13686            SharmilaTagore_81.jpg  HAPPINESS
# 13687            SharmilaTagore_82.jpg  HAPPINESS
# 13688            SharmilaTagore_83.jpg  HAPPINESS
# 13689             SharmilaTagore_9.jpg  HAPPINESS
#
# [13690 rows x 2 columns]

# %% [markdown]
# ### Show 5 Examples of Our Data

# %%
stop_counter = 0
for idx, row in df.iterrows():
    if stop_counter < 5:
        stop_counter += 1
        img_path = './images/' + row['image']
        img = mpimg.imread(img_path)
        imgplot = plt.imshow(img)
        plt.show()
        print('Label:', row['emotion'])
    else:
        break
# Out:
# Label: anger
# Label: surprise
# Label: disgust
# Label: fear
# Label: neutral

# %% [markdown]
# ### Dataset Info

# %%
dataset_size = len(df)

# %%
expressions = []
freq_table = dict()
for val in df['emotion']:
    val = val.lower()
    expressions.append(val)
    
    if freq_table.get(val):
        freq_table[val] += 1
    else:
        freq_table[val] = 1
    
expressions = list(set(expressions))

# %%
print('Images:', dataset_size)
print('Expression Types:', expressions)
# Out:
# Images: 13690
# Expression Types: ['happiness', 'contempt', 'neutral', 'disgust', 'fear', 'anger', 'surprise', 'sadness']

# %% [markdown]
# ### Distribution of Expressions in the Facial Expression Dataset

# %%
font = {'weight':'bold','size':22}
matplotlib.rc('font', **font)
plt.figure(figsize=(20, 20))
plt.bar(freq_table.keys(), freq_table.values())
# Out:
# <BarContainer object of 8 artists>
